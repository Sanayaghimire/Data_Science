# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanayaghimire/Data_Science/blob/main/Copy_of_salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
### IMPORT: ------------------------------------
import scipy.stats as stats #It has all the probability distributions available along with many statistical functions.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') # To supress warnings
# sns.set(style="darkgrid") # set the background for the graphs
from scipy.stats import skew

# from statsmodels.stats.proportion import proportions_ztest # For proportion Z-test
# from statsmodels.formula.api import ols      # For n-way ANOVA
# from statsmodels.stats.anova import anova_lm # For n-way ANOVA
# from   scipy.stats import chi2_contingency   # For Chi-Sq

# %% [markdown]
# # Read and Understand Data

# %%
#Reading the csv file AxisInsurance.csv
df = pd.read_csv('Salary Data.csv')
insured = df.copy()

# %%
# inspect data, print top 6
insured.head(6)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
# 5  29.0    Male      Bachelor's  Marketing Analyst                  2.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
# 5   55000.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Years of Experience'].plot(kind='hist', bins=20, title='Years of Experience')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('Education Level').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('Job Title').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='index', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Age', y='Years of Experience', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Years of Experience', y='Salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Education Level')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Education Level', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Job Title')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Job Title', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Years of Experience']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Gender')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Gender', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Years of Experience')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Years of Experience'].plot(kind='line', figsize=(8, 4), title='Years of Experience')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Salary'].plot(kind='line', figsize=(8, 4), title='Salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Education Level'].value_counts()
#     for x_label, grp in _df_18.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Education Level')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Job Title'].value_counts()
#     for x_label, grp in _df_19.groupby('Education Level')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Education Level')
# _ = plt.ylabel('Job Title')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='index', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['Education Level'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='index', y='Education Level', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['Job Title'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='index', y='Job Title', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='Age', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# bottom 5 rows:
insured.tail(5)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
insured.info()    #it give information about datatype of different columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insured.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
print(insured.shape)
#get the size of dataframe
print ("Rows     : " , insured.shape[0])
print ("Columns  : " , insured.shape[1])
# Out:
# (375, 6)
# Rows     :  375
# Columns  :  6

# %%
insured.isnull()
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0    False   False            False      False                False   False
# 1    False   False            False      False                False   False
# 2    False   False            False      False                False   False
# 3    False   False            False      False                False   False
# 4    False   False            False      False                False   False
# ..     ...     ...              ...        ...                  ...     ...
# 370  False   False            False      False                False   False
# 371  False   False            False      False                False   False
# 372  False   False            False      False                False   False
# 373  False   False            False      False                False   False
# 374  False   False            False      False                False   False
#
# [375 rows x 6 columns]

# %%
insured.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
#count empty value
insured.isnull().sum().values.sum()
# Out:
# 12

# %%
# insured[insured['Gender'] == '']

# %%
#drop empty or null value
insured = insured.dropna()

# %%
# seeing total value after dropping empty value
insured.shape
# Out:
# (373, 6)

# %%
insured.values
# Out:
# array([[32.0, 'Male', "Bachelor's", 'Software Engineer', 5.0, 90000.0],
#        [28.0, 'Female', "Master's", 'Data Analyst', 3.0, 65000.0],
#        [45.0, 'Male', 'PhD', 'Senior Manager', 15.0, 150000.0],
#        ...,
#        [29.0, 'Female', "Bachelor's", 'Junior Project Manager', 2.0,
#         40000.0],
#        [34.0, 'Male', "Bachelor's", 'Senior Operations Coordinator', 7.0,
#         90000.0],
#        [44.0, 'Female', 'PhD', 'Senior Business Analyst', 15.0, 150000.0]],
#       dtype=object)

# %%
print ("\nValues : \n", insured.values)
print ("\nFeatures : \n", list(insured.columns))
# print ("\nFeatures : \n", list(insured.columns.to_list()))

# print ("\nMissing values :  ", insured.isnull().sum().values.sum())

# print ("\nUnique values :  \n", insured.nunique())
# Out:
# Values :
#  [[32.0 'Male' "Bachelor's" 'Software Engineer' 5.0 90000.0]
#  [28.0 'Female' "Master's" 'Data Analyst' 3.0 65000.0]
#  [45.0 'Male' 'PhD' 'Senior Manager' 15.0 150000.0]
#  ...
#  [29.0 'Female' "Bachelor's" 'Junior Project Manager' 2.0 40000.0]
#  [34.0 'Male' "Bachelor's" 'Senior Operations Coordinator' 7.0 90000.0]
#  [44.0 'Female' 'PhD' 'Senior Business Analyst' 15.0 150000.0]]
#
# Features :
#  ['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience', 'Salary']

# %%
insured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 20.4+ KB

# %%
#changing object dtype to category  to save memory
insured['Gender']=insured['Gender'].astype("category")
insured['Education Level']=insured['Education Level'].astype("category")
insured['Job Title']=insured['Job Title'].astype("category")

# %%
insured.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    category
#  2   Education Level      373 non-null    category
#  3   Job Title            373 non-null    category
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: category(3), float64(3)
# memory usage: 18.8 KB

# %%
insured.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
#EDA = exploratory data analysis

# %%
# get counts of unique observations for each category variable
list_col=  insured.select_dtypes(['category']).columns
list_col
# Out:
# Index(['Gender', 'Education Level', 'Job Title'], dtype='object')

# %%
# get counts of unique observations for each int variable
list_col1=  insured.select_dtypes(['int']).columns
list_col1
# Out:
# Index([], dtype='object')

# %%
# get counts of unique observations for each float variable
list_col2=  insured.select_dtypes(['float']).columns
list_col2
# Out:
# Index(['Age', 'Years of Experience', 'Salary'], dtype='object')

# %%
#counting number of male and female without using value function or using set
cat=set(insured['Gender'])
Male_no=len(insured[insured['Gender']=='Male'])
Female_no=len(insured[insured['Gender']=='Female'])
print(Male_no)
print(Female_no)
# Out:
# 194
# 179

# %%
# value count

# %%
insured['Gender'].value_counts()
# Out:
# Male      194
# Female    179
# Name: Gender, dtype: int64

# %%
insured['Education Level'].value_counts()
# Out:
# Bachelor's    224
# Master's       98
# PhD            51
# Name: Education Level, dtype: int64

# %%
insured['Job Title'].value_counts()
# Out:
# Director of Marketing                 12
# Director of Operations                11
# Senior Business Analyst               10
# Senior Marketing Analyst               9
# Senior Marketing Manager               9
#                                       ..
# Junior Designer                        1
# Junior Data Scientist                  1
# Junior Data Analyst                    1
# Junior Customer Support Specialist     1
# Web Developer                          1
# Name: Job Title, Length: 174, dtype: int64

# %%
for i in list_col:
  print(i)
# Out:
# Gender
# Education Level
# Job Title

# %%
for i in list_col:
  print(dict(insured[i].value_counts()))
# Out:
# {'Male': 194, 'Female': 179}
# {"Bachelor's": 224, "Master's": 98, 'PhD': 51}
# {'Director of Marketing': 12, 'Director of Operations': 11, 'Senior Business Analyst': 10, 'Senior Marketing Analyst': 9, 'Senior Marketing Manager': 9, 'Junior Business Analyst': 8, 'Junior Financial Analyst': 7, 'Senior Project Manager': 7, 'Junior Business Development Associate': 7, 'Senior Financial Analyst': 7, 'Senior Data Scientist': 7, 'Senior Product Manager': 6, 'Senior Software Engineer': 6, 'Junior Marketing Coordinator': 6, 'Senior Financial Manager': 5, 'Senior Product Designer': 5, 'Senior Operations Manager': 5, 'Junior Marketing Specialist': 5, 'Junior Operations Analyst': 5, 'Junior Project Manager': 5, 'Senior Project Coordinator': 5, 'Senior Data Engineer': 4, 'Senior Marketing Specialist': 4, 'Senior Operations Coordinator': 4, 'Senior Business Development Manager': 4, 'Junior Product Manager': 4, 'Junior Sales Representative': 4, 'Junior Marketing Analyst': 3, 'Junior Marketing Manager': 3, 'Junior Accountant': 3, 'Senior Marketing Coordinator': 3, 'Junior Operations Manager': 3, 'Marketing Coordinator': 3, 'Senior HR Manager': 3, 'Senior Software Developer': 3, 'Sales Manager': 3, 'Senior UX Designer': 3, 'Senior Data Analyst': 3, 'Senior Scientist': 3, 'Senior Financial Advisor': 3, 'Senior Accountant': 2, 'Sales Associate': 2, 'Business Analyst': 2, 'Recruiter': 2, 'Senior Engineer': 2, 'Customer Service Manager': 2, 'Project Manager': 2, 'Senior Manager': 2, 'Junior HR Generalist': 2, 'Junior HR Coordinator': 2, 'Administrative Assistant': 2, 'Product Manager': 2, 'Senior Human Resources Manager': 2, 'Data Analyst': 2, 'Event Coordinator': 2, 'Senior Operations Analyst': 2, 'Senior Sales Representative': 2, 'Junior Account Manager': 2, 'Senior Sales Manager': 2, 'Junior Software Developer': 2, 'HR Generalist': 2, 'HR Manager': 2, 'Director of Human Resources': 2, 'Senior IT Consultant': 2, 'Director of Finance': 2, 'Marketing Analyst': 2, 'Director of Engineering': 2, 'Junior Business Operations Analyst': 2, 'Operations Manager': 2, 'Senior Consultant': 1, 'Senior Human Resources Coordinator': 1, 'Senior HR Specialist': 1, 'Senior Account Manager': 1, 'Senior HR Generalist': 1, 'Senior Human Resources Specialist': 1, 'Senior Graphic Designer': 1, 'Account Manager': 1, 'Senior IT Project Manager': 1, 'Software Manager': 1, 'VP of Operations': 1, 'VP of Finance': 1, 'UX Researcher': 1, 'UX Designer': 1, 'Training Specialist': 1, 'Technical Writer': 1, 'Technical Support Specialist': 1, 'Technical Recruiter': 1, 'Supply Chain Manager': 1, 'Supply Chain Analyst': 1, 'Strategy Consultant': 1, 'Software Project Manager': 1, 'Software Engineer': 1, 'Senior IT Support Specialist': 1, 'Software Developer': 1, 'Social Media Specialist': 1, 'Social Media Manager': 1, 'Senior Training Specialist': 1, 'Senior Software Architect': 1, 'Senior Researcher': 1, 'Senior Research Scientist': 1, 'Senior Quality Assurance Analyst': 1, 'Senior Product Marketing Manager': 1, 'Senior Product Development Manager': 1, 'Sales Representative': 1, 'Senior Marketing Director': 1, 'Senior Account Executive': 1, 'Operations Analyst': 1, 'Sales Operations Manager': 1, 'Digital Marketing Manager': 1, 'IT Manager': 1, 'Human Resources Director': 1, 'Help Desk Analyst': 1, 'Graphic Designer': 1, 'Financial Manager': 1, 'Financial Analyst': 1, 'Financial Advisor': 1, 'Director of Sales and Marketing': 1, 'Director of Sales': 1, 'Director of Product Management': 1, 'Director of Human Capital': 1, 'Director of HR': 1, 'Director of Business Development': 1, 'Director': 1, 'Digital Content Producer': 1, 'IT Support Specialist': 1, 'Data Scientist': 1, 'Data Entry Clerk': 1, 'Customer Success Rep': 1, 'Customer Success Manager': 1, 'Customer Service Representative': 1, 'Customer Service Rep': 1, 'Creative Director': 1, 'Copywriter': 1, 'Content Marketing Manager': 1, 'Chief Technology Officer': 1, 'Chief Data Officer': 1, 'CEO': 1, 'Business Intelligence Analyst': 1, 'Business Development Manager': 1, 'IT Support': 1, 'Junior Advertising Coord ...

# %%
for i in range(len(list_col)):
    print(insured[list_col[i]].value_counts())
# Out:
# Male      194
# Female    179
# Name: Gender, dtype: int64
# Bachelor's    224
# Master's       98
# PhD            51
# Name: Education Level, dtype: int64
# Director of Marketing                 12
# Director of Operations                11
# Senior Business Analyst               10
# Senior Marketing Analyst               9
# Senior Marketing Manager               9
#                                       ..
# Junior Designer                        1
# Junior Data Scientist                  1
# Junior Data Analyst                    1
# Junior Customer Support Specialist     1
# Web Developer                          1
# Name: Job Title, Length: 174, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Univariate Analysis

# %%
# # Function to create barplots that indicate percentage for each category.
def bar_perc(plot, feature):
    total = len(feature) # length of the column
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        plot.annotate(percentage, (x, y), size = 12) # annotate the percentage

# %%
len(insured[insured['sex'] == 'female'])
# Out:
# 662

# %%
no_of_male = len(insured[insured['sex'] == 'male'])
no_of_female = len(insured[insured['sex'] == 'female'])

plt.bar(['Male','Female'],[no_of_male,no_of_female],color = ['r','g'],label = ['Male','Female'])
plt.legend()
plt.show()

# %%
plot_data = dict(insured['sex'].value_counts())
plot_data
plt.bar(['male','female'],[plot_data['male'],plot_data['female']],color = ['r','g'],label = ['Male','Female'])
plt.legend()
plt.show()

# %%
insured['sex'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#Alternet
#for education level
no_of_yes = len(insured[insured['smoker'] == "yes"])
no_of_no = len(insured[insured['smoker'] == "no"])

plt.bar(["Yes","No"],[no_of_yes,no_of_no], color = ['r','g'], label=["Yes","No"])
plt.title('No of smokers and non smokers')
plt.legend()
plt.show()

# %%
plot_data = dict(insured['smoker'].value_counts())
plt.bar(plot_data.keys(),plot_data.values(),color = ['r','g'],label = plot_data.keys())
plt.legend()
plt.show()
plot_data
plot_data.keys()
# Out:
# dict_keys(['no', 'yes'])

# %%
insured['region'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# Analyzing categorical data

# %%
data = {}
list_col=  insured.select_dtypes(['category']).columns
for i in range(len(list_col)):
  values = list(insured[list_col[i]].value_counts())
  subcategory = list(insured[list_col[i]].value_counts().index)
  # data['x'] = values
  data[list_col[i]] = [subcategory,values]

data
# Out:
# {'sex': [['male', 'female'], [676, 662]],
#  'smoker': [['no', 'yes'], [1064, 274]],
#  'region': [['southeast', 'northwest', 'southwest', 'northeast'],
#   [364, 325, 325, 324]]}

# %%
# Bar Graph

# %%
plt.bar(data['sex'][0],data['sex'][1],label=['Male','Female'],
        color = ['b','r'])
plt.legend()
plt.show()

# %%
# #Alternate
# print(data['region'])
# plt.bar(data['region'][0],data['region'][1],
#         label=['southeast', 'northwest', 'southwest', 'northeast'],
#         color = ['r','b','g','k'])
# plt.title('Region')
# plt.legend()
# plt.show()

# %%
#Alternate
print(data['Education Level'])
plt.bar(data['Education Level'][0],data['Education Level'][1],
        label=data['Education Level'][0],
        color = ['g','r','b'])
plt.title('Education level')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-ee245905a8ff> in <cell line: 2>()
#       1 #Alternate
# ----> 2 print(data['Education Level'])
#       3 plt.bar(data['Education Level'][0],data['Education Level'][1],
#       4         label=data['Education Level'][0],
#       5         color = ['g','r','b'])
#
# KeyError: 'Education Level'

# %% [markdown]
# ## Bivariate & Multivariate Analysis

# %%
insured
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
corr_insured = insured[['age','children','bmi','charges']]

# %%
corr_insured.corr()
# Out:
#                age  children       bmi   charges
# age       1.000000  0.042469  0.109272  0.299008
# children  0.042469  1.000000  0.012759  0.067998
# bmi       0.109272  0.012759  1.000000  0.198341
# charges   0.299008  0.067998  0.198341  1.000000

# %%
plt.figure(figsize=(15,5))
sns.heatmap(corr_insured.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.pairplot(data=insured)
plt.show()

# %%
#Gender count plot
plt.figure(figsize=(13,5))
ax=sns.countplot(x='smoker',hue='sex',data=insured)
bar_perc(ax,insured['smoker'])

# %%
#Sex vs smoker
plt.figure(figsize=(13,5))
ax=sns.countplot(x='sex',hue='region',data=insured)
bar_perc(ax,insured['region'])

# %%
#Sex vs smoker
plt.figure(figsize=(13,5))
ax=sns.countplot(x='region',hue='smoker',data=insured)
bar_perc(ax,insured['region'])

# %%
# #smoker vs charges
sns.barplot(x=insured.smoker,y=insured.charges).set(title="Smoker vs Charges")
# Out:
# [Text(0.5, 1.0, 'Smoker vs Charges')]

# %%
#region vs smoker
plt.figure(figsize=(10,5))
ax=sns.countplot(x='region',hue='smoker',data=insured)
bar_perc(ax,insured['smoker'])
ax.set(title="Smoker vs Region")
# Out:
# [Text(0.5, 1.0, 'Smoker vs Region')]

# %%
# #smoker vs region
# plt.figure(figsize=(10,5))
# ax=sns.countplot(x='smoker',hue='region',data=insured)
# bar_perc(ax,insured['region'])
# ax.set(title="Smoker vs Region")

# %%
# plt.figure(figsize=(13,5))
# ax=sns.countplot(x='region',hue='sex',data=insured,palette='spring')
# bar_perc(ax,insured['sex'])
# ax.set(title="Sex vs Region")

# %%
insured.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# GROUP BY

# %%
insured.groupby(insured.sex).charges.mean()      #GROUP BY BY Gender
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
insured.groupby(insured['region']).charges.mean()      #GROUP BY BY Education Level
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
plot_data = dict(insured.groupby(insured['region']).charges.mean())
plot_key = list(plot_data.keys())
plot_value = list(plot_data.values())
print(plot_key)
print(plot_value)
# Out:
# ['northeast', 'northwest', 'southeast', 'southwest']
# [13406.384516385804, 12417.575373969232, 14735.41143760989, 12346.937377292308]

# %%
#Plot of Gender and Salary
sns.barplot(x=insured.sex,y=insured.charges).set(title='Gender Vs Salary')
# Out:
# [Text(0.5, 1.0, 'Gender Vs Salary')]

# %%
sns.barplot(x=insured['region'],y=insured.charges).set(title='region Vs Charges')
# Out:
# [Text(0.5, 1.0, 'region Vs Charges')]

# %%
#multivariate
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["sex"], y =insured["charges"],hue=insured["region"],ci=1).set(title= 'Charges of males and females wrt region')
plt.legend(bbox_to_anchor=(0.5, 1))
plt.show()

# %%
#multivariate
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["smoker"], y =insured["charges"],hue=insured["region"],ci=1).set(title= 'Charges of males and females wrt region')
plt.legend(bbox_to_anchor=(0.5, 1))
plt.show()

# %%
#multivariate
plt.figure(figsize=(15,7))
sns.lineplot(x = insured["sex"], y =insured["bmi"],hue=insured["region"],ci=1).set(title= 'Bmi of males and females wrt region')
plt.legend(bbox_to_anchor=(0.5, 1))
plt.show()

# %%
#Cross tab
edu_gender_salary =pd.crosstab(index=insured['region'], columns=insured.sex  , values=insured.charges, aggfunc='mean')
edu_gender_salary
# Out:
# sex              female          male
# region
# northeast  12953.203151  13854.005374
# northwest  12479.870397  12354.119575
# southeast  13499.669243  15879.617173
# southwest  11274.411264  13412.883576

# %%
gender_edu_salary=pd.crosstab(index=insured.sex, columns=insured['region']  , values=insured.charges,aggfunc='sum')
gender_edu_salary
# Out:
# region     northeast     northwest     southeast     southwest
# sex
# female  2.085466e+06  2.046699e+06  2.362442e+06  1.826455e+06
# male    2.258203e+06  1.989013e+06  3.001248e+06  2.186300e+06

# %%
# plot directly from dataframe

# %%
edu_gender_salary.plot(kind='bar',title="Region Vs Sex Vs Charges")
plt.legend(loc='upper left')
plt.show()

# %%
gender_edu_salary.plot(kind='bar',title="Sex Vs Region Vs Charges")
plt.legend(loc='upper left')
plt.show()

# %%
# converting quantitative data to qualitative
insured
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insured.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#creating groups of age
category = pd.cut(insured.age,bins=[15,20,25,30,35,40,45,50,55,60,65],labels=['15-20','20-25','25-30','30-35','35-40','40-45','45-50','50-55','55-60','60-65'])
insured.insert(1,'AgeGroup',category)

# %%
insured
# Out:
#       age AgeGroup     sex     bmi  children smoker     region      charges
# 0      19    15-20  female  27.900         0    yes  southwest  16884.92400
# 1      18    15-20    male  33.770         1     no  southeast   1725.55230
# 2      28    25-30    male  33.000         3     no  southeast   4449.46200
# 3      33    30-35    male  22.705         0     no  northwest  21984.47061
# 4      32    30-35    male  28.880         0     no  northwest   3866.85520
# ...   ...      ...     ...     ...       ...    ...        ...          ...
# 1333   50    45-50    male  30.970         3     no  northwest  10600.54830
# 1334   18    15-20  female  31.920         0     no  northeast   2205.98080
# 1335   18    15-20  female  36.850         0     no  southeast   1629.83350
# 1336   21    20-25  female  25.800         0     no  southwest   2007.94500
# 1337   61    60-65  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 8 columns]

# %%
age_group = insured.groupby(insured.AgeGroup).charges.mean()
age_group
# Out:
# AgeGroup
# 15-20     8713.482413
# 20-25     9529.919689
# 25-30    10086.132420
# 30-35    10929.364789
# 35-40    12366.022844
# 40-45    14538.651124
# 45-50    15013.603477
# 50-55    16988.005623
# 55-60    17145.494360
# 60-65    21063.163398
# Name: charges, dtype: float64

# %%
category1=pd.cut(insured['Years of Experience'],bins=[0,5,10,15,20],labels=['0-5','5-10','10-15','15-20'])
insured.insert(6,'Exp_group',category1)

# %%
insured.head()
# Out:
#     Age AgeGroup  Gender Education Level          Job Title  \
# 0  32.0    30-35    Male      Bachelor's  Software Engineer
# 1  28.0    25-30  Female        Master's       Data Analyst
# 2  45.0    40-45    Male             PhD     Senior Manager
# 3  36.0    35-40  Female      Bachelor's    Sales Associate
# 4  52.0    50-55    Male        Master's           Director
#
#    Years of Experience Exp_group    Salary
# 0                  5.0       0-5   90000.0
# 1                  3.0       0-5   65000.0
# 2                 15.0     10-15  150000.0
# 3                  7.0      5-10   60000.0
# 4                 20.0     15-20  200000.0

# %%
age_group.plot(kind='bar',title="Agebins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Agebins vs Avg Salary'}, xlabel='AgeGroup'>

# %%
Exp_bin_cat = insured.groupby(insured.Exp_group).Salary.mean()
Exp_bin_cat
# Out:
# Exp_group
# 0-5       49367.372881
# 5-10      92578.947368
# 10-15    118230.769231
# 15-20    159140.625000
# Name: Salary, dtype: float64

# %%
Exp_bin_cat.plot(kind='bar',title="Exp_bins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Agebins vs Avg Salary'}, xlabel='Exp_group'>

# %%
#multi variate data analysis
insured.groupby(['Gender','Education Level','Exp_group']).Salary.mean()
# Out:
# Gender  Education Level  Exp_group
# Female  Bachelor's       0-5           47040.816327
#                          5-10          88225.806452
#                          10-15         92941.176471
#                          15-20        120000.000000
#         Master's         0-5           58750.000000
#                          5-10          93000.000000
#                          10-15        115000.000000
#                          15-20        170000.000000
#         PhD              0-5                    NaN
#                          5-10                   NaN
#                          10-15        147727.272727
#                          15-20        153636.363636
# Male    Bachelor's       0-5           49158.474576
#                          5-10          90833.333333
#                          10-15        125384.615385
#                          15-20        121875.000000
#         Master's         0-5           75000.000000
#                          5-10         102941.176471
#                          10-15        126250.000000
#                          15-20        172750.000000
#         PhD              0-5                    NaN
#                          5-10         110000.000000
#                          10-15        126250.000000
#                          15-20        164333.333333
# Name: Salary, dtype: float64

# %%
insured.groupby(['Gender','Education Level','Exp_group']).Salary.mean().unstack().plot(kind='bar',title="Exp_bins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs Avg Salary'}, xlabel='Gender,Education Level'>

# %%
insured.groupby(['Gender','Education Level','Exp_group']).Salary.mean().unstack().plot(kind='bar',title="Exp_bins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs Avg Salary'}, xlabel='Gender,Education Level'>

# %%
insured.groupby(['Education Level','Gender','Exp_group']).Salary.mean().unstack().plot(kind='bar',title="Exp_bins vs Avg Salary")
# Out:
# <Axes: title={'center': 'Exp_bins vs Avg Salary'}, xlabel='Education Level,Gender'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=insured["Education Level"],y=insured["Salary"],hue=insured['Gender'],ci=0).set(title= 'Age and Bmi of Males and Females')
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %%
sns.barplot(x='Education Level',y='expenses',hue='sex',data=insured).set(title="Fig 2:BMI group and Charges " )

# %%
sns.relplot(x=insured['Years of Experience'], y=insured["Salary"], hue=insured['Gender'], size=  insured['Education Level'],
            sizes=(40, 400), palette="spring",
            height=6, data=insured).set(title='Salary by Education Level,Gender,Experience');

# %%
insured

# %%
sns.relplot(x=insured['Salary'], y=insured['Years of Experience'], hue=insured['Gender'], size=  insured['Education Level'],
            sizes=(40, 400), palette="spring",
            height=6, data=insured).set(title='Salary by Education Level,Gender,Experience');

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# # 1.Prove (or disprove) that the medical claims made by the people who smoke is greater than those who don't?

# %% [markdown]
# <div class ="alert alert-block alert-info">
#
# ---
#
#
#     <font size=3><b>    Step 1: Define null and alternative hypothesis</b></font><br>
# $\ H_0  :  \mu_1 <= \mu_2  $ The average charges of smokers is less than or equal to nonsmokers
#  <br>
#
#
# $\ H_a  :\mu_1 > \mu_2 $ The average charges of smokers is greater than nonsmokers  <br>
# </div>

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 2: Decide the significance level. If P values is less than alpha reject the null hypothesis.</b></font>
#
# α = 0.05

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 3: Identify the test</b></font>
#
# Standard deviation of the population is not known  ,will perform a T stat test .  The > sign in alternate hypothesis indicate  test is right tailed, that is all z values that would cause us to reject null hypothesis are in just one tail to the right of  sampling  distribution curve.

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 4: Calculate the test-statistics and p-value</b></font>

# %%
smoker=insured.loc[insured.smoker=="yes"]
smoker.head()

# %%
smoker.count()

# %%
nonsmoker=insured.loc[insured.smoker=='no']
nonsmoker.head()

# %%
nonsmoker.count()

# %%
# Adjusting the size of the rows to be equal
nonsmoker = nonsmoker[0:274]
charges_yes = smoker.expenses
charges_no = nonsmoker.expenses

# %%
print(f'Average Cost charged to Insurance for smoker is {charges_yes.mean()} and nonsmoker is {charges_no.mean()} ')

# %%
#smoker vs charges
sns.boxplot(x=insured.expenses,y=insured.smoker,data=insured).set(title="Fig:1 Smoker vs Charges")

# %%
charges_no

# %%
alpha = 0.05
t_statistic_1, p_value_1 = stats.ttest_ind(charges_yes, charges_no)
p_value_onetail=p_value_1/2

print("Test statistic = {} , Pvalue ={} , OnetailPvalue = {}".format(t_statistic_1,p_value_1, p_value_onetail ))

# %%
if p_value_1 < alpha :
    print(f"Conclusion:Since P value {p_value_onetail} is less than alpha {alpha} " )
    # print("Reject Null Hypothesis that Average charges for smokers are less than or equal to nonsmoker.")

else:
    print("Conclusion:Since P value {} is greater than alpha {} ". format (p_value_onetail,alpha))
    # print("Failed to Reject Null Hypothesis that Average charges for smokers are less than nonsmoker.")

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 5: Decide whethere to  reject or failed to reject null hypothesis</b></font><br>
#     We reject the null hypothesis and can conclude that people who smoke have on an average larger medical claim compared to people who don't smoke. Similar result can also been seen in Fig no.1 Smokers Vs Charges

# %% [markdown]
# # 2.Prove (or disprove) with statistical evidence that the BMI of females is different from that of males.

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     Let $\mu_1 \mu_2 $ and be the respective population means for BMI of males and BMI of females<br>
#     <font size=3><b>    Step 1: Define null and alternative hypothesis</b></font><br>
# $\ H_0  : \mu_1 - \mu_2 = 0$ There is no difference between the BMI of Male  and BMI of female.<br>
# $\ H_a  : \mu_1 - \mu_2 !=0 $ There is difference between the BMI of Male and BMI of female. <br>
#
#
# </div>

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 2: Decide the significance level</b></font>
#
# α = 0.05

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 3:Identify the test</b></font><br>Standard deviation of the population is not known ,will perform a T stat test.Not equal to sign in alternate hypothesis indicate its a two tailed test.

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 4: Calculate the test-statistics and p-value</b></font>

# %%
#get all observation for male.
df_male=insured.loc[insured.sex=="male"]
#get all observation for females
df_female=insured.loc[insured.sex=="female"]

# %%
#get bmi of male and female
bmi_female=df_female.bmi
bmi_male=df_male.bmi

# %%
sns.distplot(bmi_male,color='green',hist=False)
sns.distplot(bmi_female,color='red',hist=False)

# %%
df_female.bmi.mean()

# %%
df_male.bmi.mean()

# %%
# get statistic and p value
t_statistic_2, p_value_2 = stats.ttest_ind(bmi_male, bmi_female)
print("tstats = ",t_statistic_2, ", pvalue = ", p_value_2)

# %%
if p_value_2 <alpha :
    print("Conclusion:Since P value {} is less than alpha {} ". format (p_value_2,alpha) )
    print("Reject Null Hypothesis  that there is no difference in bmi of men and bmi of female.")

else:
    print("Conclusion:Since P value {} is greater than alpha {} ". format (p_value_2,alpha))
    print("Failed to Reject Null Hypothesis  that there is difference in bmi of men and bmi of female .")

# %% [markdown]
# <div class ="alert alert-block alert-info">
#     <font size=3><b>Step 5: Decide to reject or accept null hypothesis</b></font><br>
#      We fail to reject the null hypothesis and can conclude that There is no difference between BMI of Female and BMI of Male.

# %% [markdown]
# ### Recommendation
# - Based on EDA and statistical  evidence it can be seen that  customer who smoke or   have higher  BMI  have more higher claims. We can encourage customers to quit smoking by providing them  incentive points  for talking to life coach, get help for improving lifestyle habits,  Quit Tobacco- 28 day program. Give gift cards when customer accumulates specific number of points.
# - We can have Active wellness programs which can help up reduce claims related to BMI.
# - High BMI  is primarily because of unhealthy life choices. We can provide customers with Diet plans and wellness health coaches which can help them to make right choices.
# - Provide discount coupons  for Gym  or  fitness devices encouraging customers to exercise.
