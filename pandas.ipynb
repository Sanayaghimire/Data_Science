# %%
import pandas as pd
df = pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
#csv file is called as comma seperated files in data science or in python
df = pd.read_csv('Salary Data.csv', nrows=13)
df
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 0    32    Male      Bachelor's      Software Engineer                    5
# 1    28  Female        Master's           Data Analyst                    3
# 2    45    Male             PhD         Senior Manager                   15
# 3    36  Female      Bachelor's        Sales Associate                    7
# 4    52    Male        Master's               Director                   20
# 5    29    Male      Bachelor's      Marketing Analyst                    2
# 6    42  Female        Master's        Product Manager                   12
# 7    31    Male      Bachelor's          Sales Manager                    4
# 8    26  Female      Bachelor's  Marketing Coordinator                    1
# 9    38    Male             PhD       Senior Scientist                   10
# 10   29    Male        Master's     Software Developer                    3
# ...

# %%
df = pd.read_csv('Salary Data.csv')
row,col =df.shape
# .shape give the dimension of whole data ...dataframe have 2 dimension row and col
print("The number of rows = ", row)
print("The number of columns = ", col)
# Out:
# The number of rows =  375
# The number of columns =  6

# %%
#in data science whole data means population and 
#if you r viwewing certain data only then it is called sample

df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.tail()
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
df=df.sample(frac=1)
df
# Out:
#       Age  Gender Education Level                            Job Title  \
# 179  46.0    Male        Master's               Director of Operations
# 106  30.0  Female      Bachelor's             Digital Content Producer
# 315  44.0    Male      Bachelor's             Senior Software Engineer
# 367  41.0    Male      Bachelor's               Senior Product Manager
# 223  42.0  Female        Master's       Senior Human Resources Manager
# ..    ...     ...             ...                                  ...
# 20   34.0  Female        Master's                     Business Analyst
# 251  38.0    Male        Master's                 Senior IT Consultant
# 48   38.0    Male             PhD                     Senior Scientist
# 293  35.0    Male      Bachelor's  Senior Business Development Manager
# 5    29.0    Male      Bachelor's                    Marketing Analyst
#
#      Years of Experience    Salary
# 179                 20.0  170000.0
# 106                  3.0   50000.0
# ...

# %%
#iloc ....middle data extract garna
df.iloc[10:20]
# Out:
#       Age  Gender Education Level                      Job Title  \
# 137  30.0  Female      Bachelor's       Junior Marketing Manager
# 361  34.0    Male      Bachelor's  Senior Operations Coordinator
# 337  34.0    Male      Bachelor's  Senior Operations Coordinator
# 220  48.0    Male        Master's          Director of Marketing
# 60   51.0  Female        Master's         Director of Operations
# 254  35.0  Female      Bachelor's       Senior Marketing Analyst
# 360  29.0  Female      Bachelor's         Junior Project Manager
# 10   29.0    Male        Master's             Software Developer
# 190  39.0  Female      Bachelor's       Senior Account Executive
# 7    31.0    Male      Bachelor's                  Sales Manager
#
#      Years of Experience    Salary
# 137                  4.0   50000.0
# 361                  7.0   90000.0
# 337                  7.0   90000.0
# 220                 19.0  170000.0
# 60                  23.0  170000.0
# ...

# %%
df.iloc[10:20, 0:3] #row , col
# Out:
#       Age  Gender Education Level
# 137  30.0  Female      Bachelor's
# 361  34.0    Male      Bachelor's
# 337  34.0    Male      Bachelor's
# 220  48.0    Male        Master's
# 60   51.0  Female        Master's
# 254  35.0  Female      Bachelor's
# 360  29.0  Female      Bachelor's
# 10   29.0    Male        Master's
# 190  39.0  Female      Bachelor's
# 7    31.0    Male      Bachelor's

# %%
df[['Age', 'Education Level', 'Job Title']].head()
# Out:
#       Age Education Level                       Job Title
# 179  46.0        Master's          Director of Operations
# 106  30.0      Bachelor's        Digital Content Producer
# 315  44.0      Bachelor's        Senior Software Engineer
# 367  41.0      Bachelor's          Senior Product Manager
# 223  42.0        Master's  Senior Human Resources Manager

# %%
df=pd.read_csv('Salary Data.csv', usecols=['Age', 'Education Level', 'Job Title'])
df
# Out:
#       Age Education Level                      Job Title
# 0    32.0      Bachelor's              Software Engineer
# 1    28.0        Master's                   Data Analyst
# 2    45.0             PhD                 Senior Manager
# 3    36.0      Bachelor's                Sales Associate
# 4    52.0        Master's                       Director
# ..    ...             ...                            ...
# 370  35.0      Bachelor's       Senior Marketing Analyst
# 371  43.0        Master's         Director of Operations
# 372  29.0      Bachelor's         Junior Project Manager
# 373  34.0      Bachelor's  Senior Operations Coordinator
# 374  44.0             PhD        Senior Business Analyst
#
# [375 rows x 3 columns]

# %%
df=pd.read_csv('Salary Data.csv')
df[df['Gender']=='Female']
# Out:
#       Age  Gender Education Level                 Job Title  \
# 1    28.0  Female        Master's              Data Analyst
# 3    36.0  Female      Bachelor's           Sales Associate
# 6    42.0  Female        Master's           Product Manager
# 8    26.0  Female      Bachelor's     Marketing Coordinator
# 11   48.0  Female      Bachelor's                HR Manager
# ..    ...     ...             ...                       ...
# 366  31.0  Female      Bachelor's  Junior Financial Analyst
# 368  44.0  Female             PhD      Senior Data Engineer
# 370  35.0  Female      Bachelor's  Senior Marketing Analyst
# 372  29.0  Female      Bachelor's    Junior Project Manager
# 374  44.0  Female             PhD   Senior Business Analyst
#
#      Years of Experience    Salary
# 1                    3.0   65000.0
# 3                    7.0   60000.0
# 6                   12.0  120000.0
# 8                    1.0   45000.0
# 11                  18.0  140000.0
# ...

# %%
len(df[df['Gender']=='Male'])
# Out:
# 194

# %%
df[(df['Gender'] == 'Male') & (df['Salary'] > 6000)]
# Out:
#       Age Gender Education Level                      Job Title  \
# 0    32.0   Male      Bachelor's              Software Engineer
# 2    45.0   Male             PhD                 Senior Manager
# 4    52.0   Male        Master's                       Director
# 5    29.0   Male      Bachelor's              Marketing Analyst
# 7    31.0   Male      Bachelor's                  Sales Manager
# ..    ...    ...             ...                            ...
# 365  43.0   Male        Master's          Director of Marketing
# 367  41.0   Male      Bachelor's         Senior Product Manager
# 369  33.0   Male      Bachelor's        Junior Business Analyst
# 371  43.0   Male        Master's         Director of Operations
# 373  34.0   Male      Bachelor's  Senior Operations Coordinator
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 2                   15.0  150000.0
# 4                   20.0  200000.0
# 5                    2.0   55000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB
